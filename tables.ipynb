# %% [markdown]
# <a href="https://colab.research.google.com/github/st064560/my_python/blob/master/tables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('для анализа.xlsx', index_col='ФИО') 
#df.head() 
df = df.replace(0, np.nan)
df
# Out:
#      Уровень должности  ... Руководство подразделением
# ФИО                     ...
# 1                    2  ...                        NaN
# 4                    5  ...                        4.0
# 12                   1  ...                        1.0
# 15                   4  ...                        1.0
# 2                    2  ...                        1.0
# 21                   2  ...                        1.0
# 23                   2  ...                        NaN
# 27                   2  ...                        3.0
# 28                   2  ...                        4.0
# 29                   1  ...                        1.0
# 3                    4  ...                        3.0
# 31                   1  ...                        NaN
# 32                   2  ...                        1.0
# 35                   2  ...                        3.0
# 36                   4  ...                        3.0
# 37                   2  ...                        1.0
# ...

# %%
import seaborn as sns

cm = sns.light_palette("green", as_cmap=True)

s = df.iloc[:, 3:32].style.background_gradient(cmap=cm)
s
# Out:
# <style  type="text/css" >
#     #T_ca09bc84_8aba_11ea_ae5d_0242ac1c0002row0_col0 {
#             background-color:  #4daa4d;
#             color:  #000000;
#         }    #T_ca09bc84_8aba_11ea_ae5d_0242ac1c0002row0_col1 {
#             background-color:  #4daa4d;
#             color:  #000000;
#         }    #T_ca09bc84_8aba_11ea_ae5d_0242ac1c0002row0_col2 {
#             background-color:  #72bf72;
#             color:  #000000;
#         }    #T_ca09bc84_8aba_11ea_ae5d_0242ac1c0002row0_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_ca09bc84_8aba_11ea_ae5d_0242ac1c0002row0_col4 {
#             background-color:  #399f39;
#             color:  #000000;
#         }    #T_ca09bc84_8aba_11ea_ae5d_0242ac1c0002row0_col5 {
#             background-color:  #72bf72;
#             color:  #000000;
#         }    #T_ca09bc84_8aba_11ea_ae5d_0242ac1c0002row0_col6 {
#             background-color:  #72bf72;
#             color:  #000000;
# ...

# %%
df.replace(0, np.nan)

# %%
import pandas as pd
import numpy as np
df = pd.read_excel('для анализа.xlsx', index_col='ФИО') 
#df.head() 

df = df.replace(0 ,np.nan)
df.iloc[:, 3:32].round(0)
#df
(df.iloc[:, 3:32]
    .style
    .background_gradient(cmap='viridis', low=.5, high=0)
    .highlight_null('red'))
# Out:
# <style  type="text/css" >
#     #T_af285540_8abc_11ea_ae5d_0242ac1c0002row0_col0 {
#             background-color:  #6ece58;
#             color:  #000000;
#             : ;
#         }    #T_af285540_8abc_11ea_ae5d_0242ac1c0002row0_col1 {
#             background-color:  #6ece58;
#             color:  #000000;
#             : ;
#         }    #T_af285540_8abc_11ea_ae5d_0242ac1c0002row0_col2 {
#             background-color:  #35b779;
#             color:  #000000;
#             : ;
#         }    #T_af285540_8abc_11ea_ae5d_0242ac1c0002row0_col3 {
#             background-color:  #fde725;
#             color:  #000000;
#             : ;
#         }    #T_af285540_8abc_11ea_ae5d_0242ac1c0002row0_col4 {
#             background-color:  #6ece58;
#             color:  #000000;
#             : ;
#         }    #T_af285540_8abc_11ea_ae5d_0242ac1c0002row0_col5 {
#             background-color:  #1f9e89;
#             color:  #000000;
#             : ;
# ...

# %%
# Out:
#      Планирование комплекса керновых исследований  ...  Руководство подразделением
# ФИО                                                ...
# 1                                               3  ...                         NaN
# 4                                               4  ...                         4.0
# 12                                              2  ...                         1.0
# 15                                              3  ...                         1.0
# 2                                               3  ...                         1.0
# 21                                              2  ...                         1.0
# 23                                              3  ...                         NaN
# 27                                              1  ...                         3.0
# 28                                              1  ...                         4.0
# 29                                              2  ...                         1.0
# ...

# %%
df.iloc[:, 3:32]
# Out:
#      Планирование комплекса керновых исследований  ...  Руководство подразделением
# ФИО                                                ...
# 1                                               3  ...                           0
# 4                                               4  ...                           4
# 12                                              2  ...                           1
# 15                                              3  ...                           1
# 20                                              3  ...                           1
# 21                                              2  ...                           1
# 23                                              3  ...                           0
# 27                                              1  ...                           3
# 28                                              1  ...                           4
# 29                                              2  ...                           1
# ...

# %%
df.shape
# Out:
# (28, 32)

# %%
df.dtypes
# Out:
# Уровень должности                                  int64
# Должность                                         object
# Планирование комплекса ГИС                         int64
# Планирование комплекса керновых исследований       int64
# Стандартизация показаний методов ГИС               int64
# Методики определения УЭС                           int64
# Теория и обработка ИНГК-С                          int64
# Теория и обработка АКШ                             int64
# Теория и обработка ЯМК                             int64
# Теория и обработка имиджеров                       int64
# Теория и обработка диэлектрического сканера        int64
# Теория и обработка триаксиального ИК               int64
# Программирование Python, C++ и др.                 int64
# Методики выделения коллекторов                     int64
# Петроф. моделирование ФЕС                          int64
# Петроф. моделирование нетрадиционных коллект.      int64
# ...

# %%
df.describe()
# Out:
#        Уровень должности  ...  Руководство подразделением
# count          28.000000  ...                   28.000000
# mean            2.535714  ...                    1.535714
# std             1.137969  ...                    1.201300
# min             1.000000  ...                    0.000000
# 25%             2.000000  ...                    1.000000
# 50%             2.000000  ...                    1.000000
# 75%             3.000000  ...                    3.000000
# max             5.000000  ...                    4.000000
#
# [8 rows x 31 columns]

# %%
df[df['Планирование комплекса ГИС'] > 3]
# Out:
#      Уровень должности  ... Руководство подразделением
# ФИО                     ...
# 4                    5  ...                          4
# 30                   4  ...                          3
# 35                   2  ...                          3
# 36                   4  ...                          3
# 43                   3  ...                          3
# 53                   5  ...                          0
# 62                   3  ...                          1
#
# [7 rows x 32 columns]

# %%
filter_large = df['Планирование комплекса ГИС'] > 3
filter_first_class = df['Уровень должности'] > 3

df[filter_large & filter_first_class]
# Out:
#      Уровень должности  ... Руководство подразделением
# ФИО                     ...
# 4                    5  ...                          4
# 30                   4  ...                          3
# 36                   4  ...                          3
# 53                   5  ...                          0
#
# [4 rows x 32 columns]
